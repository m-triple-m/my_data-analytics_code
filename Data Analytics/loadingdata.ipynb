# %%
import pandas as pd

# %%
df = pd.read_csv('Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df.shape
# Out:
# (800, 13)

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
# series
gen = df.Generation
gen
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 795    6
# 796    6
# 797    6
# 798    6
# 799    6
# Name: Generation, Length: 800, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(gen)
# Out:
# pandas.core.series.Series

# %%
gen.unique()
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df['Type 1'].unique().shape
# Out:
# (18,)

# %%
df[['Type 1', 'Name']]
# Out:
#       Type 1                   Name
# 0      Grass              Bulbasaur
# 1      Grass                Ivysaur
# 2      Grass               Venusaur
# 3      Grass  VenusaurMega Venusaur
# 4       Fire             Charmander
# ..       ...                    ...
# 795     Rock                Diancie
# 796     Rock    DiancieMega Diancie
# 797  Psychic    HoopaHoopa Confined
# 798  Psychic     HoopaHoopa Unbound
# 799     Fire              Volcanion
#
# [800 rows x 2 columns]

# %%
df.iloc[4]
# Out:
# #                      4
# Name          Charmander
# Type 1              Fire
# Type 2               NaN
# Total                309
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed                 65
# Generation             1
# Legendary          False
# Name: 4, dtype: object

# %%
df[4:10]
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %%
df[['Type 1', 'Name']][10:30]
# Out:
#     Type 1                     Name
# 10   Water                Wartortle
# 11   Water                Blastoise
# 12   Water  BlastoiseMega Blastoise
# 13     Bug                 Caterpie
# 14     Bug                  Metapod
# 15     Bug               Butterfree
# 16     Bug                   Weedle
# 17     Bug                   Kakuna
# 18     Bug                 Beedrill
# 19     Bug    BeedrillMega Beedrill
# 20  Normal                   Pidgey
# 21  Normal                Pidgeotto
# 22  Normal                  Pidgeot
# 23  Normal      PidgeotMega Pidgeot
# 24  Normal                  Rattata
# 25  Normal                 Raticate
# 26  Normal                  Spearow
# 27  Normal                   Fearow
# 28  Poison                    Ekans
# 29  Poison                    Arbok

# %%
df[['Name', 'HP']].tail(20)
# Out:
#                       Name   HP
# 780  PumpkabooAverage Size   49
# 781    PumpkabooSmall Size   44
# 782    PumpkabooLarge Size   54
# 783    PumpkabooSuper Size   59
# 784  GourgeistAverage Size   65
# 785    GourgeistSmall Size   55
# 786    GourgeistLarge Size   75
# 787    GourgeistSuper Size   85
# 788               Bergmite   55
# 789                Avalugg   95
# 790                 Noibat   40
# 791                Noivern   85
# 792                Xerneas  126
# 793                Yveltal  126
# 794       Zygarde50% Forme  108
# 795                Diancie   50
# 796    DiancieMega Diancie   50
# 797    HoopaHoopa Confined   80
# 798     HoopaHoopa Unbound   80
# 799              Volcanion   80

# %%
df.set_index('Name', inplace=True)

# %%
df.loc['Pikachu']
# Out:
# #                   25
# Type 1        Electric
# Type 2             NaN
# Total              320
# HP                  35
# Attack              55
# Defense             40
# Sp. Atk             50
# Sp. Def             50
# Speed               90
# Generation           1
# Legendary        False
# Name: Pikachu, dtype: object

# %%
df[df['HP'] < 100]
# Out:
#                          #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                1    Grass  Poison    318  45      49       49
# Ivysaur                  2    Grass  Poison    405  60      62       63
# Venusaur                 3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3    Grass  Poison    625  80     100      123
# Charmander               4     Fire     NaN    309  39      52       43
# ...                    ...      ...     ...    ...  ..     ...      ...
# Diancie                719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie    719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined    720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound     720  Psychic    Dark    680  80     160       60
# Volcanion              721     Fire   Water    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
df[df['Type 1'].str.startswith('G')]
# Out:
#                          #  Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                1   Grass  Poison    318  45      49       49
# Ivysaur                  2   Grass  Poison    405  60      62       63
# Venusaur                 3   Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3   Grass  Poison    625  80     100      123
# Sandshrew               27  Ground     NaN    300  50      75       85
# ...                    ...     ...     ...    ...  ..     ...      ...
# PumpkabooSuper Size    710   Ghost   Grass    335  59      66       70
# GourgeistAverage Size  711   Ghost   Grass    494  65      90      122
# GourgeistSmall Size    711   Ghost   Grass    494  55      85      122
# GourgeistLarge Size    711   Ghost   Grass    494  75      95      122
# GourgeistSuper Size    711   Ghost   Grass    494  85     100      122
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
df[df['Type 1'].str.startswith('G')]['Type 1']
# Out:
# Name
# Bulbasaur                 Grass
# Ivysaur                   Grass
# Venusaur                  Grass
# VenusaurMega Venusaur     Grass
# Sandshrew                Ground
#                           ...
# PumpkabooSuper Size       Ghost
# GourgeistAverage Size     Ghost
# GourgeistSmall Size       Ghost
# GourgeistLarge Size       Ghost
# GourgeistSuper Size       Ghost
# Name: Type 1, Length: 134, dtype: object

# %%
df[df['Type 1'].str.startswith('G')]['Type 1'].unique()
